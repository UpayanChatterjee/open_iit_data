# %%
import numpy as np
import pandas as pd
import seaborn as sns
import nltk

# %%
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

# %%
ps = PorterStemmer()
wordnet=WordNetLemmatizer()

# %%
#f=open('my-file.txt','rU')
#raw=file.read()
#sentences=nltk.sent_tokenize(raw)
#tokens = nltk.word_tokenize(raw)
#text = nltk.Text(tokens)

# %%
lemmatizer = WordNetLemmatizer()

# %%
# Lemmatization
#for i in range(len(sentences)):
#    words = nltk.word_tokenize(sentences[i])
#    words = [lemmatizer.lemmatize(word) for word in words if word not in set(stopwords.words('english'))]
#    sentences[i] = ' '.join(words)

# %%
#print(sentences)

# %%
#print(corpus)

# %%
# Creating the Bag of Words model
#from sklearn.feature_extraction.text import CountVectorizer
#cv = CountVectorizer(max_features = 1500)
#X = cv.fit_transform(corpus).toarray()

# %%
# Creating the TF-IDF model
#from sklearn.feature_extraction.text import TfidfVectorizer
#cv = TfidfVectorizer()
#X = cv.fit_transform(corpus).toarray()

# %%
#print(X)

# %%
df = pd.read_csv("pairs-label-training.csv")
df
# Out:
#         text1  text2  label
# 0          98    651      0
# 1         696   1870      1
# 2        1073   1620      0
# 3         167    633      0
# 4           4    640      0
# ...       ...    ...    ...
# 155946    546   1512      1
# 155947    720   1902      1
# 155948   1112   1591      0
# 155949    396   1472      1
# 155950   1021   1680      0
#
# [155951 rows x 3 columns]

# %%
file=open('text_and_id_sorted.txt','rU')
content = file.readlines()
# value1 = df.iat[1, 1]
# print(value1)
# print(content[value1-1])
# print(content)
# Out:
# C:\Users\Upayan\AppData\Local\Temp\ipykernel_8600\3769112695.py:1: DeprecationWarning: 'U' mode is deprecated
#   file=open('text_and_id_sorted.txt','rU')

# %%
from sklearn.model_selection import train_test_split

# %%
y = df['label']
X = df.drop('label',axis=1)

# %%
X
# Out:
#         text1  text2
# 0          98    651
# 1         696   1870
# 2        1073   1620
# 3         167    633
# 4           4    640
# ...       ...    ...
# 155946    546   1512
# 155947    720   1902
# 155948   1112   1591
# 155949    396   1472
# 155950   1021   1680
#
# [155951 rows x 2 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(
  X,y , random_state=104,test_size=0.2, shuffle=True)

# %%
X_test.shape
# Out:
# (31191, 2)

# %%
X_train.shape
# Out:
# (124760, 2)

# %%
X_train.reset_index(inplace=True, drop=True)
X_train
# Out:
#         text1  text2
# 0         320   1678
# 1         610   1996
# 2         104    550
# 3         630   1492
# 4         402   1910
# ...       ...    ...
# 124755    344   1854
# 124756    664   1636
# 124757   1065   1515
# 124758    520   1692
# 124759    502   1590
#
# [124760 rows x 2 columns]

# %%
# file=open('text_and_id_sorted.txt','rU')

# %%
# value1 = X_test.iat[0, 1]
# print(value1)
# value2 = X_test.iat[0, 0]
# print(value2)

# %%
# content = file.readlines()

# %%
# print(content[value1-1])

# %%
# print(content[1])

# %%
# line1 = content[value1-1]
# line2 = content[value2-1]
# print(line1)
# print(line2)
# final_line=line1+line2
# print(final_line)
# review = re.sub('[^a-zA-Z]', ' ', final_line)
# print(review)

# %%
# value1 = X_test.iat[31000, 1]
# print(value1)
# # print(content[1900])
# line1=content[1900]
# print(line1)
# #line1 = content[value1-1]
# # line1=content[1500]

# %%
len(X_train.index)
# Out:
# 124760

# %%
content[1999]
# Out:
# '2000 This game was used effectively in sports education . \n'

# %%
corpus = []
#content = file.readlines()
for row in range(len(X_train.index)):
    value1 = X_train.iat[row, 1]
    value2 = X_train.iat[row, 0]
    line1 = content[value1-1]
    line2 = content[value2-1]
    final_line=line1+line2
    review = re.sub('[^a-zA-Z]', ' ', final_line)
    review = review.lower()
    review = review.split()
    #review = [ps.stem(word) for word in review if not word in set(stopwords.words('english'))]
    review = [lemmatizer.lemmatize(word) for word in review if not word in set(stopwords.words('english'))]
    review = ' '.join(review)
    corpus.append(review)

# %%
with open(r'./corpus.txt', 'w') as fp:
    for item in corpus:
        # write each item on a new line
        fp.write("%s\n" % item)

# %%
corpus
# Out:
# ['air slows falling object earth suppose player change course football passing head towards goal heading',
#  'bring end thread together put knot end thread rear view mirror car plane mirror driver reversing car speed driver see rear view mirror image truck parked behind car speed image truck appears approach driver',
#  'imagined telephone would one day become inseparable part daily life got people village ensured job helped settle city provided money time crisis jobber therefore became person authority power began demanding money gift favour controlling life worker',
#  'effect net force direction moving object see mirror learn others physical appearance look like',
#  'fire safety fire important element day day life suitable tool instrument help woman perform various activity well grow interest woman housewife towards work',
#  'think reach velocity home manager acquires quality able behave well others convince',
#  'peasant peasant woman official residence rashtrapati bhavan',
# ...

# %%
# import json
# with open('corpus.txt', 'w') as f:
#     f.write(json.dumps(corpus))

# #Now read the file back into a Python list object
# with open('corpus.txt', 'r') as f:
#     corpus = json.loads(f.read())

# %%
# my_line=open('corpus.txt','rU')
# corpus=my_line.read()
# print(corpus)

# %%
# Creating the TF-IDF model
from sklearn.feature_extraction.text import TfidfVectorizer
cv = TfidfVectorizer()
X_train_final = cv.fit_transform(corpus).toarray()

# %%
X_train_final.shape
# Out:
# (124760, 4366)

# %%
corpus_val = []
#content = file.readlines()
for row in range(len(X_test.index)):
    value1 = X_test.iat[row, 1]
    value2 = X_test.iat[row, 0]
    line1 = content[value1-1]
    line2 = content[value2-1]
    final_line=line1+line2
    review = re.sub('[^a-zA-Z]', ' ', final_line)
    review = review.lower()
    review = review.split()
    #review = [ps.stem(word) for word in review if not word in set(stopwords.words('english'))]
    review = [lemmatizer.lemmatize(word) for word in review if not word in set(stopwords.words('english'))]
    review = ' '.join(review)
    corpus_val.append(review)

# %%
corpus_val
# Out:
# ['globe longitude shown series semi circle run pole pole passing equator mean lost capacity work',
#  'atom extremely small size expressed term take water filled test tube hold inverted mouth delivery tube collect oxygen test tube',
#  'easier work buy equipment listed properly per size structure according necessity us soil condition think farmer would treat soil field quick lime calcium oxide slaked lime calcium hydroxide chalk calcium carbonate',
#  'pigment particle mix vehicle way particle distributed equal distance whole liquid never wring woollen clothes take water',
#  'men born misconception nation constitutes largest community among group man',
#  'ranabhaire gowda jayagowda gidde gowda kempananje gowda others ruled touch physician keep instrument medicine right place',
#  'depending mother convenience better bathe child morning hour day loos job reason cannot find employment work',
# ...

# %%
# import json
# with open('corpus_val.txt', 'w') as f:
#   f.write(json.dumps(corpus_val))

#   #Now read the file back into a Python list object
# with open('corpus.txt', 'r') as f:
#     corpus_val = json.loads(f.read())

# %%
# Creating the TF-IDF model
from sklearn.feature_extraction.text import TfidfVectorizer
cv = TfidfVectorizer()
X_val_final = cv.fit_transform(corpus_val).toarray()

# %%
X_val_final.shape
# Out:
# (31191, 4366)

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential([
    Dense(32, activation='relu', input_shape=(4366,)),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid'),
])

# %%
model.compile(optimizer='sgd',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
hist = model.fit(X_train_final, y_train,
          batch_size=32, epochs=10,
          validation_data=(X_val_final, y_test))
# Out:
# Epoch 1/10
# 3899/3899 [==============================] - 9s 2ms/step - loss: 0.6867 - accuracy: 0.5456 - val_loss: 0.6746 - val_accuracy: 0.7788
# Epoch 2/10
# 3899/3899 [==============================] - 5s 1ms/step - loss: 0.6067 - accuracy: 0.8083 - val_loss: 0.4592 - val_accuracy: 0.9081
# Epoch 3/10
# 3899/3899 [==============================] - 5s 1ms/step - loss: 0.2478 - accuracy: 0.9572 - val_loss: 0.1187 - val_accuracy: 0.9904
# Epoch 4/10
# 3899/3899 [==============================] - 5s 1ms/step - loss: 0.0721 - accuracy: 0.9953 - val_loss: 0.0458 - val_accuracy: 0.9987
# Epoch 5/10
# 3899/3899 [==============================] - 7s 2ms/step - loss: 0.0332 - accuracy: 0.9987 - val_loss: 0.0248 - val_accuracy: 0.9994
# Epoch 6/10
# 3899/3899 [==============================] - 5s 1ms/step - loss: 0.0201 - accuracy: 0.9993 - val_loss: 0.0165 - val_accuracy: 0.9994
# Epoch 7/10
# ...

# %%
model.evaluate(X_val_final, y_test)[1]
# Out:
# 975/975 [==============================] - 1s 743us/step - loss: 0.0071 - accuracy: 0.9994
# 0.9993908405303955

# %% [markdown]
# trying to change the contents of the stopword list

# %%
to_remove = ['he','him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself']
new_stopwords = set(stopwords.words('english')).difference(to_remove)
# stopwords.words('english')
# print(len(stopwords.words('english')))

# %%
import tensorflow as tf

# %%
import tensorflow_hub as hub
import tensorflow_text as text

# %%
preprocess_url = "https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3"
encoder_url = "https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/4"

# %%
bert_preprocess_model = hub.KerasLayer(preprocess_url)
text_preprocessed = bert_preprocess_model(corpus)
text_preprocessed.keys()
# text_preprocessed['input_type_ids']
# Out:
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.data_structures has been moved to tensorflow.python.trackable.data_structures. The old module will be deleted in version 2.11.
# dict_keys(['input_type_ids', 'input_mask', 'input_word_ids'])

# %%
# gpu_options = tf.GPUOptions(allow_growth=True)
# session = tf.InteractiveSession(config=tf.ConfigProto(gpu_options=gpu_options))

# %%
bert_model = hub.KerasLayer(encoder_url)
bert_results = bert_model(text_preprocessed)
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In [55], line 2
#       1 bert_model = hub.KerasLayer(encoder_url)
# ----> 2 bert_results = bert_model(text_preprocessed)
#
# File c:\Users\Upayan\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File c:\Users\Upayan\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_hub\keras_layer.py:237, in KerasLayer.call(self, inputs, training)
#     234   else:
# ...

# %%
bert_results.keys()

# %%
model = Sequential([
    Dense(32, activation='relu', input_shape=(768,)),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid'),
])

model.compile(optimizer='sgd',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
hist = model.fit(X_train_final, y_train,
          batch_size=32, epochs=10,
          validation_data=(X_val_final, y_test))

# %%
#corpus = []
#for i in range(len(sentences)):
#    review = re.sub('[^a-zA-Z]', ' ', sentences[i])
#    review = review.lower()
#    review = review.split()
#    #review = [ps.stem(word) for word in review if not word in set(stopwords.words('english'))]
#    review = [lemmatizer.lemmatize(word) for word in review if not word in set(stopwords.words('english'))]
#    review = ' '.join(review)
#    corpus.append(review)

# %%
#print(file.read())

# %%
#for row in range(len(X_test.index)):
#    print(X_test[['text1' , 'text2']].iloc[row])

# %%
#X_test.loc[0]

# %%
#sentences=nltk.sent_tokenize(paragraph)

# %%
#print(sentences)

# %%
#words=nltk.sent_tokenize(sentences)
