# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('./pairs-label-training.csv')
df
# Out:
#         text1  text2  label
# 0          98    651      0
# 1         696   1870      1
# 2        1073   1620      0
# 3         167    633      0
# 4           4    640      0
# ...       ...    ...    ...
# 155946    546   1512      1
# 155947    720   1902      1
# 155948   1112   1591      0
# 155949    396   1472      1
# 155950   1021   1680      0
#
# [155951 rows x 3 columns]

# %%
df.iat[0, 0]
# Out:
# 98

# %%
len(df.index)
# Out:
# 155951

# %%
arr = np.zeros(2001)
for i in range(0, len(df.index)):
    arr[df.iat[i, 0]] +=1
    arr[df.iat[i, 1]] +=1
# print(arr)
arr
# Out:
# array([  0., 201., 201., ..., 251.,   0., 251.])

# %%
c = 0
for i in range(0, len(arr)):
    if arr[i] == 0:
        print(i)
        c+=1
print(c)
# Out:
# 0
# 201
# 202
# 203
# 204
# 205
# 206
# 207
# 208
# 209
# 210
# 211
# 212
# 213
# 214
# 215
# 216
# 217
# 218
# 219
# 220
# 221
# 222
# 223
# 224
# 225
# 226
# 227
# 228
# 229
# 230
# 231
# 232
# 233
# 234
# 235
# 236
# 237
# 238
# 239
# 240
# 241
# 242
# 243
# 244
# 245
# 246
# 247
# 248
# 249
# 250
# 251
# 252
# 253
# 254
# 255
# 256
# 257
# 258
# 259
# 260
# 261
# 262
# 263
# 264
# 265
# 266
# 267
# 268
# 269
# 270
# 271
# 272
# 273
# 274
# 275
# 276
# 277
# 278
# 279
# 280
# 281
# 282
# 283
# 284
# 285
# 286
# 287
# 288
# 289
# 290
# 291
# 292
# 293
# 294
# 295
# 296
# 297
# 298
# 299
# 301
# 303
# 305
# 307
# 309
# 311
# 313
# 315
# 317
# 319
# 321
# 323
# 325
# 327
# 329
# 331
# 333
# 335
# 337
# 339
# 341
# 343
# 345
# 347
# 349
# 351
# 353
# 355
# 357
# 359
# 361
# 363
# 365
# 367
# 369
# 371
# 373
# 375
# 377
# 379
# 381
# 383
# 385
# 387
# 389
# 391
# 393
# 395
# 397
# 399
# 401
# 403
# 405
# 407
# 409
# 411
# 413
# 415
# 417
# 419
# 421
# 423
# 425
# 427
# 429
# 431
# 433
# ...
